# %% [markdown]
# ## Group 10 Midterm 2
# #### INFO 4602
#
# #### Group Members
# - Ben Brechtel
# - Talon Knowlton
# - Sidney Lentz
# - Andrew Logue

# %%
import pandas as pd
import numpy as np
import altair as alt
alt.data_transformers.enable('csv')
# Out:
# DataTransformerRegistry.enable('csv')

# %% [markdown]
# ### Import Dataset

# %%
#read in dataset and find data for deaths by obesity
Obesity = pd.read_csv('Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023')
Obesity1 = Obesity.query("Condition == 'Obesity'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 #read in dataset and find data for deaths by obesity
# ----> 2 Obesity = pd.read_csv('Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023')
#       3 Obesity1 = Obesity.query("Condition == 'Obesity'")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023'

# %%
#test case
Obesity1 = Obesity1.query("Group == 'By Total'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #test case
# ----> 2 Obesity1 = Obesity1.query("Group == 'By Total'")
#
# NameError: name 'Obesity1' is not defined

# %%
#test case- query by state==Colorado
Obesity1.query("State == 'Colorado'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #test case- query by state==Colorado
# ----> 2 Obesity1.query("State == 'Colorado'")
#
# NameError: name 'Obesity1' is not defined

# %%
new =  Obesity1['State'].to_list
Obesity1 = Obesity1.drop(Obesity1[Obesity1.State == 'United States'].index) #don't want 'United States' as a state value
#df = df.drop(df[df.score < 50].index)
this = alt.Chart(Obesity1).mark_bar().encode(x = 'State', y = 'COVID-19 Deaths')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 new =  Obesity1['State'].to_list
#       2 Obesity1 = Obesity1.drop(Obesity1[Obesity1.State == 'United States'].index) #don't want 'United States' as a state value
#       3 #df = df.drop(df[df.score < 50].index)
#
# NameError: name 'Obesity1' is not defined

# %%
Obesity1.groupby(['State']).agg({'COVID-19 Deaths':'sum'})
# Out:
#                       COVID-19 Deaths
# State
# Alabama                        1199.0
# Alaska                          164.0
# Arizona                        3422.0
# Arkansas                        922.0
# California                    11602.0
# Colorado                       2144.0
# Connecticut                     651.0
# Delaware                        440.0
# District of Columbia            363.0
# Florida                        7687.0
# Georgia                        3142.0
# Hawaii                          150.0
# Idaho                           716.0
# Illinois                       4440.0
# Indiana                        2236.0
# Iowa                           1096.0
# Kansas                          915.0
# Kentucky                       1502.0
# Louisiana                      1664.0
# Maine                           111.0
# Maryland                       1876.0
# Massachusetts                   803.0
# Michigan                       2800.0
# Minnesota                      1604.0
# Mississippi                    1306.0
# Missouri                       1476.0
# Montana                         617.0
# Nebraska                        616.0
# Nevada                         1151.0
# New Hampshire                   205.0
# New Jersey                     1804.0
# New Mexico                     1347.0
# New York                       1880.0
# New York City                  1572.0
# North Carolina                 2712.0
# North Dakota                    301.0
# Ohio                           3042.0
# Oklahoma                       3284.0
# Oregon                         1002.0
# Pennsylvania                   3648.0
# Puerto Rico                     423.0
# Rhode Island                    278.0
# South Carolina                 3000.0
# South Dakota                    360.0
# Tennessee                      2500.0
# Texas                         13342.0
# Utah                           1020.0
# Vermont                          90.0
# Virginia                       1076.0
# Washington                     1879.0
# West Virginia                   538.0
# Wisconsin                      3180.0
# Wyoming                         293.0

# %% [markdown]
# ### Part 1

# %%
this = alt.Chart(Obesity1).mark_bar().encode(x = 'State', y = 'COVID-19 Deaths'
).properties(
title=['COVID-19 Deaths By State']   
)

this
# Out:
# alt.Chart(...)

# %%
deaths=Obesity1
Obesity1.head()
# Out:
#      Data As Of  Start Date    End Date     Group  Year  Month    State  \
# 390  03/19/2023  01/01/2020  03/18/2023  By Total   NaN    NaN  Alabama
# 391  03/19/2023  01/01/2020  03/18/2023  By Total   NaN    NaN  Alabama
# 392  03/19/2023  01/01/2020  03/18/2023  By Total   NaN    NaN  Alabama
# 393  03/19/2023  01/01/2020  03/18/2023  By Total   NaN    NaN  Alabama
# 394  03/19/2023  01/01/2020  03/18/2023  By Total   NaN    NaN  Alabama
#
#     Condition Group Condition ICD10_codes Age Group  COVID-19 Deaths  \
# 390         Obesity   Obesity     E65-E68      0-24              NaN
# 391         Obesity   Obesity     E65-E68     25-34             31.0
# 392         Obesity   Obesity     E65-E68     35-44             79.0
# 393         Obesity   Obesity     E65-E68     45-54            109.0
# 394         Obesity   Obesity     E65-E68     55-64            175.0
#
#      Number of Mentions                                               Flag
# 390                 NaN  One or more data cells have counts between 1-9...
# 391                31.0                                                NaN
# 392                79.0                                                NaN
# 393               109.0                                                NaN
# 394               175.0                                                NaN

# %%
#find unique state values and then sort them in alphabetical order
state_group = (deaths['State']).values.tolist()
state_group_set=set(state_group) 
state_group_set=list(state_group_set)
state_group_set.sort()

#create state dropdown feature
state_dropdown = alt.binding_select(options=state_group_set, name='Select State')
state_selection = alt.selection_single(fields=['State'], bind=state_dropdown)


##BAR HERE
bar = alt.Chart(deaths).mark_bar().encode(
    x = alt.X('Age Group:N', sort='x'),
    y = 'COVID-19 Deaths:Q',
    color = 'Age Group'
).properties(
    title=['COVID-19 Deaths By Age Group With Obesity As A Condition In Selected State'],
    width=700
).add_selection(
    state_selection
).transform_filter(
    state_selection
)

bar
# Out:
# alt.Chart(...)
